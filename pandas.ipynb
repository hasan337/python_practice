# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
l1=['hassan', 'mahsun', 'mahfooz']
l1
# Out:
# ['hassan', 'mahsun', 'mahfooz']

# %%
s1=pd.Series(l1, name='Areas' )
s1
# Out:
# 0     hassan
# 1     mahsun
# 2    mahfooz
# Name: Areas, dtype: object

# %%
l2=[True,False,True]
s2=pd.Series(l2,index=l1)
s2
# Out:
# hassan      True
# mahsun     False
# mahfooz     True
# dtype: bool

# %% [markdown]
# **Creating Series from Dictionary**

# %%
D={
    'charminar':100,
    'shaali banda':101,
    'shakker gunj':200,
    'barkus':99
}
D
# Out:
# {'charminar': 100, 'shaali banda': 101, 'shakker gunj': 200, 'barkus': 99}

# %%
s1=pd.Series(D)
s1
s1['barkus']
# Out:
# 99

# %% [markdown]
# **Custom Indexing**

# %%
a=[123,456,789,777,999]
b=['A','B','C','D','E']
c=pd.Series(a, index=b)
c
# Out:
# A    123
# B    456
# C    789
# D    777
# E    999
# dtype: int64

# %% [markdown]
# **Creating Series from read.csv method**

# %%
data=pd.read_csv('/kaggle/input/videogamesales/vgsales.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
d=pd.read_csv('/kaggle/input/videogamesales/vgsales.csv', usecols=['Name'] )
d
# Out:
#                                                    Name
# 0                                            Wii Sports
# 1                                     Super Mario Bros.
# 2                                        Mario Kart Wii
# 3                                     Wii Sports Resort
# 4                              Pokemon Red/Pokemon Blue
# ...                                                 ...
# 16593                Woody Woodpecker in Crazy Castle 5
# 16594                     Men in Black II: Alien Escape
# 16595  SCORE International Baja 1000: The Official Game
# 16596                                        Know How 2
# 16597                                  Spirits & Spells
#
# [16598 rows x 1 columns]

# %% [markdown]
# **Attributes**

# %%
s1.index
# Out:
# Index(['charminar', 'shaali banda', 'shakker gunj', 'barkus'], dtype='object')

# %%
s1.values
# Out:
# array([100, 101, 200,  99])

# %%
s1.ndim
# Out:
# 1

# %%
s1.shape
# Out:
# (4,)

# %%
s1.unique
# Out:
# <bound method Series.unique of charminar       100
# shaali banda    101
# shakker gunj    200
# barkus           99
# dtype: int64>

# %%
s1.name

# %% [markdown]
# **Methods of Series(Function)**

# %%
e=pd.read_csv('/kaggle/input/videogamesales/vgsales.csv', usecols=['Global_Sales']  )
e
# Out:
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16598 rows x 1 columns]

# %%
e.max()
# Out:
# Global_Sales    82.74
# dtype: float64

# %%
e.min()
# Out:
# Global_Sales    0.01
# dtype: float64

# %%
e.sum()
# Out:
# Global_Sales    8920.44
# dtype: float64

# %%
e.prod()
# Out:
# /opt/conda/lib/python3.10/site-packages/numpy/core/_methods.py:53: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# Global_Sales    inf
# dtype: float64

# %%
e1=pd.Series([-1,2,3,1])
e1
# Out:
# 0   -1
# 1    2
# 2    3
# 3    1
# dtype: int64

# %%
e1.prod()
# Out:
# -6

# %%
e.idxmax()
e.max()
# Out:
# Global_Sales    82.74
# dtype: float64

# %%
e.idxmin()
# Out:
# Global_Sales    15980
# dtype: int64

# %%
len(e)
# Out:
# 16598

# %% [markdown]
# **Head,Tail,Sorted,List,dict,Type (Functions)**

# %%
e.head()
# Out:
#    Global_Sales
# 0         82.74
# 1         40.24
# 2         35.82
# 3         33.00
# 4         31.37

# %%
e.head(11)
# Out:
#     Global_Sales
# 0          82.74
# 1          40.24
# 2          35.82
# 3          33.00
# 4          31.37
# 5          30.26
# 6          30.01
# 7          29.02
# 8          28.62
# 9          28.31
# 10         24.76

# %%
e.tail()
# Out:
#        Global_Sales
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01

# %%
sorted(e)
# Out:
# ['Global_Sales']

# %%
s=pd.Series(['hj','mj','mj'])
s
list(s)
# Out:
# ['hj', 'mj', 'mj']

# %%
dict(e)
# Out:
# {'Global_Sales': 0        82.74
#  1        40.24
#  2        35.82
#  3        33.00
#  4        31.37
#           ...
#  16593     0.01
#  16594     0.01
#  16595     0.01
#  16596     0.01
#  16597     0.01
#  Name: Global_Sales, Length: 16598, dtype: float64}

# %%
type(e)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **All,Any,any_Prefix and any_suffix (Functions)**

# %%
s=pd.Series([True,False,True,True])
s1=pd.Series([True,True,True,True])

# %%
all(s)
# Out:
# False

# %%
all(s1)
# Out:
# True

# %%
any(s)
# Out:
# True

# %%
any(s1)
# Out:
# True

# %%
x=pd.Series([10,20,30,40,50],index=('h1','h2','h3','h4','h5'))
x
# Out:
# h1    10
# h2    20
# h3    30
# h4    40
# h5    50
# dtype: int64

# %%
x.add_prefix('pre')
# Out:
# preh1    10
# preh2    20
# preh3    30
# preh4    40
# preh5    50
# dtype: int64

# %%
x.add_suffix('pro')
# Out:
# h1pro    10
# h2pro    20
# h3pro    30
# h4pro    40
# h5pro    50
# dtype: int64

# %% [markdown]
# **Sorting and Inplace **

# %%
import numpy as np
import pandas as pd

# %%
a=np.random.randint(0,20,10)
l=list(a)
l
# Out:
# [16, 7, 1, 16, 2, 1, 12, 13, 1, 9]

# %%
s=pd.Series(l)
s
# Out:
# 0    16
# 1     7
# 2     1
# 3    16
# 4     2
# 5     1
# 6    12
# 7    13
# 8     1
# 9     9
# dtype: int64

# %%
s.sort_values(ascending=False, inplace=True)
s
# Out:
# 0    16
# 3    16
# 7    13
# 6    12
# 9     9
# 1     7
# 4     2
# 2     1
# 5     1
# 8     1
# dtype: int64

# %%
s.sort_index()
# Out:
# 0    16
# 1     7
# 2     1
# 3    16
# 4     2
# 5     1
# 6    12
# 7    13
# 8     1
# 9     9
# dtype: int64

# %% [markdown]
# **Drop Duplicates()Functions**

# %%
b=pd.Series(['Hassan','Mahsun','Mahfooz','Mahsun','AbdulRahman','Mahsun'],index=('id1','id2','id3','id4','id5','id6'))
b
# Out:
# id1         Hassan
# id2         Mahsun
# id3        Mahfooz
# id4         Mahsun
# id5    AbdulRahman
# id6         Mahsun
# dtype: object

# %%
b.drop_duplicates(keep=False)
# Out:
# id1         Hassan
# id3        Mahfooz
# id5    AbdulRahman
# dtype: object

# %%
b
# Out:
# id1         Hassan
# id2         Mahsun
# id3        Mahfooz
# id4         Mahsun
# id5    AbdulRahman
# id6         Mahsun
# dtype: object

# %%
d=pd.read_csv('/kaggle/input/videogamesales/vgsales.csv',usecols=['Name'])
d
# Out:
#                                                    Name
# 0                                            Wii Sports
# 1                                     Super Mario Bros.
# 2                                        Mario Kart Wii
# 3                                     Wii Sports Resort
# 4                              Pokemon Red/Pokemon Blue
# ...                                                 ...
# 16593                Woody Woodpecker in Crazy Castle 5
# 16594                     Men in Black II: Alien Escape
# 16595  SCORE International Baja 1000: The Official Game
# 16596                                        Know How 2
# 16597                                  Spirits & Spells
#
# [16598 rows x 1 columns]

# %%
d.count()
# Out:
# Name    16598
# dtype: int64

# %%
d.drop_duplicates()
# Out:
#                                                     Name
# 0                                             Wii Sports
# 1                                      Super Mario Bros.
# 2                                         Mario Kart Wii
# 3                                      Wii Sports Resort
# 4                               Pokemon Red/Pokemon Blue
# ...                                                  ...
# 16589  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...
# 16590  Eiyuu Densetsu: Sora no Kiseki Material Collec...
# 16592                                           Plushees
# 16593                 Woody Woodpecker in Crazy Castle 5
# 16596                                         Know How 2
#
# [11493 rows x 1 columns]

# %%
d.drop_duplicates(keep=False)
# Out:
#                                                     Name
# 0                                             Wii Sports
# 2                                         Mario Kart Wii
# 3                                      Wii Sports Resort
# 4                               Pokemon Red/Pokemon Blue
# 6                                  New Super Mario Bros.
# ...                                                  ...
# 16589  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...
# 16590  Eiyuu Densetsu: Sora no Kiseki Material Collec...
# 16592                                           Plushees
# 16593                 Woody Woodpecker in Crazy Castle 5
# 16596                                         Know How 2
#
# [8718 rows x 1 columns]

# %% [markdown]
# **Filling the Null Values**

# %%
p=pd.Series([100,200,None,400,505],index=('mumbai','dehli','jaipur','hyderbad','hyd2'))
p
# Out:
# mumbai      100.0
# dehli       200.0
# jaipur        NaN
# hyderbad    400.0
# hyd2        505.0
# dtype: float64

# %%
p.isna()
# Out:
# mumbai      False
# dehli       False
# jaipur       True
# hyderbad    False
# hyd2        False
# dtype: bool

# %%
mask=p.dropna()
mask
# Out:
# mumbai      100.0
# dehli       200.0
# hyderbad    400.0
# hyd2        505.0
# dtype: float64

# %%
p.fillna(300)
# Out:
# mumbai      100.0
# dehli       200.0
# jaipur      300.0
# hyderbad    400.0
# hyd2        505.0
# dtype: float64

# %% [markdown]
# **Describe**

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
data1=pd.read_csv('/kaggle/input/videogamesales/vgsales.csv',usecols=['Year'])
data1
# Out:
#          Year
# 0      2006.0
# 1      1985.0
# 2      2008.0
# 3      2009.0
# 4      1996.0
# ...       ...
# 16593  2002.0
# 16594  2003.0
# 16595  2008.0
# 16596  2010.0
# 16597  2003.0
#
# [16598 rows x 1 columns]

# %%
data1.isna()
# Out:
#         Year
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 16593  False
# 16594  False
# 16595  False
# 16596  False
# 16597  False
#
# [16598 rows x 1 columns]

# %%
data1.dropna()
# Out:
#          Year
# 0      2006.0
# 1      1985.0
# 2      2008.0
# 3      2009.0
# 4      1996.0
# ...       ...
# 16593  2002.0
# 16594  2003.0
# 16595  2008.0
# 16596  2010.0
# 16597  2003.0
#
# [16327 rows x 1 columns]

# %%
data1.drop_duplicates()
data1.count()
# Out:
# Year    16327
# dtype: int64

# %%
z=pd.read_csv('/kaggle/input/videogamesales/vgsales.csv', usecols=['Name','Global_Sales'], index_col='Name' )
z
# Out:
#                                                   Global_Sales
# Name
# Wii Sports                                               82.74
# Super Mario Bros.                                        40.24
# Mario Kart Wii                                           35.82
# Wii Sports Resort                                        33.00
# Pokemon Red/Pokemon Blue                                 31.37
# ...                                                        ...
# Woody Woodpecker in Crazy Castle 5                        0.01
# Men in Black II: Alien Escape                             0.01
# SCORE International Baja 1000: The Official Game          0.01
# Know How 2                                                0.01
# Spirits & Spells                                          0.01
#
# [16598 rows x 1 columns]

# %%
z[0:10:2]
# Out:
#                            Global_Sales
# Name
# Wii Sports                        82.74
# Mario Kart Wii                    35.82
# Pokemon Red/Pokemon Blue          31.37
# New Super Mario Bros.             30.01
# New Super Mario Bros. Wii         28.62

# %% [markdown]
# **Reindexing**

# %%
y=pd.Series([11,22,33],index=('A','B','C'))
y
# Out:
# A    11
# B    22
# C    33
# dtype: int64

# %%
y.reindex(index=['A','y','B','Z'])
# Out:
# A    11.0
# y     NaN
# B    22.0
# Z     NaN
# dtype: float64

# %% [markdown]
# **Get()Function**

# %%
print(z.get('Contra',default='No Match Founded'))
# Out:
# No Match Founded

# %%
Z=pd.read_csv('/kaggle/input/videogamesales/vgsales.csv', usecols=['Genre'] )
Z
# Out:
#               Genre
# 0            Sports
# 1          Platform
# 2            Racing
# 3            Sports
# 4      Role-Playing
# ...             ...
# 16593      Platform
# 16594       Shooter
# 16595        Racing
# 16596        Puzzle
# 16597      Platform
#
# [16598 rows x 1 columns]

# %%
Z.value_counts(ascending=True)
# Out:
# Genre
# Puzzle           582
# Strategy         681
# Fighting         848
# Simulation       867
# Platform         886
# Racing          1249
# Adventure       1286
# Shooter         1310
# Role-Playing    1488
# Misc            1739
# Sports          2346
# Action          3316
# Name: count, dtype: int64

# %%
xyz=pd.read_csv('/kaggle/input/videogamesales/vgsales.csv', usecols=['Global_Sales'] )
xyz
# Out:
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16598 rows x 1 columns]

# %%
def category(num):
    if num>=30:
        return'super'
    elif num>=30:
        return'Average'
    else:
        return'belowAverage'

# %%
B=xyz.apply(category)
B
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_42/4113959524.py in ?()
# ----> 1 B=xyz.apply(category)
#       2 B
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, func, axis, raw, result_type, args, **kwargs)
#    9419             result_type=result_type,
#    9420             args=args,
#    9421             kwargs=kwargs,
#    9422         )
# -> 9423         return op.apply().__finalize__(self, method="apply")
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py in ?(self)
#     674         # raw
#     675         elif self.raw:
#     676             return self.apply_raw()
#     677
# --> 678         return self.apply_standard()
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py in ?(self)
#     797     def apply_standard(self):
# --> 798         results, res_index = self.apply_series_generator()
# ...
